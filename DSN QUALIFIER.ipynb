# %%
import os
import numpy as np
import pandas as pd

# %%
TRAIN = pd.read_csv("C://Users//Abdulrazaq//Documents//py learn//Zindi//zindi_dataset//dsn_hackathon_qualif//Train.csv")

# %%
TRAIN
# Out:
#         Applicant_ID  form_field1  form_field2  form_field3  form_field4  \
# 0      Apcnt_1000000       3436.0      0.28505       1.6560       0.0000
# 1      Apcnt_1000004       3456.0      0.67400       0.2342       0.0000
# 2      Apcnt_1000008       3276.0      0.53845       3.1510       0.0000
# 3      Apcnt_1000012       3372.0      0.17005       0.5050       0.0000
# 4      Apcnt_1000016       3370.0      0.77270       1.1010       0.0000
# ...              ...          ...          ...          ...          ...
# 55995   Apcnt_999968       3740.0      0.01730       0.0000       0.0000
# 55996   Apcnt_999972       3360.0      2.01145       0.6252       0.0000
# 55997   Apcnt_999980       3500.0      0.76640       0.0000       0.0000
# 55998   Apcnt_999988       3280.0      0.05235       2.0916       2.2212
# 55999   Apcnt_999996       3522.0      0.46930       0.0000       0.0000
#
#        form_field5  form_field6  form_field7  form_field8  form_field9  ...  \
# ...

# %%
TRAIN.head(5)
# Out:
#     Applicant_ID  form_field1  form_field2  form_field3  form_field4  \
# 0  Apcnt_1000000       3436.0      0.28505       1.6560          0.0
# 1  Apcnt_1000004       3456.0      0.67400       0.2342          0.0
# 2  Apcnt_1000008       3276.0      0.53845       3.1510          0.0
# 3  Apcnt_1000012       3372.0      0.17005       0.5050          0.0
# 4  Apcnt_1000016       3370.0      0.77270       1.1010          0.0
#
#    form_field5  form_field6  form_field7  form_field8  form_field9  ...  \
# 0        0.000          0.0   10689720.0     252072.0    4272776.0  ...
# 1        0.000          0.0     898979.0     497531.0    9073814.0  ...
# 2        6.282          NaN     956940.0          NaN     192944.0  ...
# 3        0.000     192166.0    3044703.0     385499.0    3986472.0  ...
# 4        0.000       1556.0     214728.0     214728.0    1284089.0  ...
#
#    form_field42  form_field43  form_field44  form_field45  form_field46  \
# ...

# %%
TRAIN.columns
# Out:
# Index(['Applicant_ID', 'form_field1', 'form_field2', 'form_field3',
#        'form_field4', 'form_field5', 'form_field6', 'form_field7',
#        'form_field8', 'form_field9', 'form_field10', 'form_field11',
#        'form_field12', 'form_field13', 'form_field14', 'form_field15',
#        'form_field16', 'form_field17', 'form_field18', 'form_field19',
#        'form_field20', 'form_field21', 'form_field22', 'form_field23',
#        'form_field24', 'form_field25', 'form_field26', 'form_field27',
#        'form_field28', 'form_field29', 'form_field30', 'form_field31',
#        'form_field32', 'form_field33', 'form_field34', 'form_field35',
#        'form_field36', 'form_field37', 'form_field38', 'form_field39',
#        'form_field40', 'form_field41', 'form_field42', 'form_field43',
#        'form_field44', 'form_field45', 'form_field46', 'form_field47',
#        'form_field48', 'form_field49', 'form_field50', 'default_status'],
#       dtype='object')

# %%
#FUNCTION TO CHECK NULL VALUES


def check_null(col):
    return TRAIN[col].isnull().sum()
column = col = ['Applicant_ID', 'form_field1', 'form_field2', 'form_field3',
       'form_field4', 'form_field5', 'form_field6', 'form_field7',
       'form_field8', 'form_field9', 'form_field10', 'form_field11',
       'form_field12', 'form_field13', 'form_field14', 'form_field15',
       'form_field16', 'form_field17', 'form_field18', 'form_field19',
       'form_field20', 'form_field21', 'form_field22', 'form_field23',
       'form_field24', 'form_field25', 'form_field26', 'form_field27',
       'form_field28', 'form_field29', 'form_field30', 'form_field31',
       'form_field32', 'form_field33', 'form_field34', 'form_field35',
       'form_field36', 'form_field37', 'form_field38', 'form_field39',
       'form_field40', 'form_field41', 'form_field42', 'form_field43',
       'form_field44', 'form_field45', 'form_field46', 'form_field47',
       'form_field48', 'form_field49', 'form_field50', 'default_status']
#nan_vals = check_null(col = column)
#nan_vals.sort_values(ascending = False)

nan_vals = check_null(col = column)
non_nan = (len(TRAIN)- nan_vals)
nan_val = pd.DataFrame({"non_nan":non_nan, "nan_val":nan_vals})
nan_val = nan_val.sort_values(by =["non_nan"])
##.sort_values(ascending = False)

nan_val
# Out:
#                 non_nan  nan_val
# form_field40      12271    43729
# form_field31      16592    39408
# form_field41      17771    38229
# form_field11      24579    31421
# form_field45      24683    31317
# form_field23      27877    28123
# form_field30      30491    25509
# form_field35      32852    23148
# form_field15      33525    22475
# form_field48      35111    20889
# form_field22      35600    20400
# form_field46      40096    15904
# form_field21      40146    15854
# form_field8       42640    13360
# form_field6       42640    13360
# form_field24      42703    13297
# form_field16      42964    13036
# form_field17      44849    11151
# form_field50      44944    11056
# form_field18      45598    10402
# form_field12      46105     9895
# form_field27      46701     9299
# form_field9       47992     8008
# form_field26      48562     7438
# form_field13      50111     5889
# form_field32      50550     5450
# form_field25      50550     5450
# ...

# %%
#columns i could try dropping
"form_field40 	12271 	43729
form_field31 	16592 	39408Maximum tenure on all education loans ( days)
form_field41 	17771 	38229Utilization of line on active auto loans (%)
form_field11 	24579 	31421,he amount of dues collected post-default where the due amount was more than 500 (in NGN)
form_field45 	24683 	31317 Number of mortgage loans on which the borrower has missed 2 payments
form_field23 	27877 	28123 Average utilization of line on all active credit cards activated in last 1 year (%)
form_field30 	30491 	25509Maximum tenure on all auto loans (in days)
form_field35 	32852 	23148 Number of revolving credit cards over the last 2 years on which the borrower has missed 1 payment
form_field15 	33525 	22475The estimated market value of a property owned/used by the borrower (in NGN)
form_field48 	35111 	20889 Undefined Variable

# %%
TRAIN.drop(columns = ["form_field31","form_field41","form_field11",
                     "form_field45","form_field23","form_field30","form_field35"],inplace = True)

# %%
from sklearn.preprocessing import LabelEncoder
Encode = LabelEncoder()
TRAIN["default_status"] = Encode.fit_transform(TRAIN.default_status.values) #Encodes default-satus column

# %%
corr_matrix = TRAIN.corr()
corr_matrix["default_status"].sort_values(ascending=False)
# Out:
# default_status    1.000000
# form_field42      0.329039
# form_field21      0.325634
# form_field22      0.322421
# form_field16      0.275836
# form_field17      0.269507
# form_field18      0.265692
# form_field2       0.226313
# form_field46      0.196138
# form_field3       0.193603
# form_field36      0.167306
# form_field40      0.164199
# form_field49      0.152407
# form_field38      0.151966
# form_field34      0.151109
# form_field4       0.147548
# form_field39      0.145949
# form_field19      0.134433
# form_field20      0.127612
# form_field5       0.088912
# form_field24      0.064261
# form_field14      0.008272
# form_field12     -0.042858
# form_field50     -0.049732
# form_field48     -0.060161
# form_field44     -0.066595
# form_field13     -0.089314
# form_field7      -0.113481
# form_field15     -0.127264
# form_field33     -0.140934
# form_field43     -0.165155
# form_field6      -0.165438
# form_field10     -0.170323
# form_field9      -0.206441
# ...

# %%
# function for new train dataframe with columns
def create_frame(col_name):
    new_df = pd.DataFrame()
    new_df[col_name] = TRAIN[col_name]
   # col = TRAIN.train_col
    new_df

# %% [markdown]
# #### FORM_FIELD 47

# %%
TRAIN.drop(columns = ["Applicant_ID"],inplace = True)

# %%
new_train = pd.DataFrame()
new_train["form_field47"]= TRAIN["form_field47"]
new_train.head()
# Out:
#   form_field47
# 0       charge
# 1       charge
# 2       charge
# 3       charge
# 4       charge

# %%
#encode categories
import sklearn
from sklearn.preprocessing import LabelEncoder
encoder = LabelEncoder()
new_train["form_field47"] = encoder.fit_transform(new_train.form_field47.values)

# %% [markdown]
# ### FORM FIELD 14

# %%
new_train["form_field14"]= TRAIN["form_field14"]
new_train.head()
# Out:
#    form_field47  form_field14
# 0             0      96375139
# 1             0      28141427
# 2             0      16576457
# 3             0      48187375
# 4             0      28141427

# %% [markdown]
# FORM_FIELD28

# %%
"""Number of days since last missed payment on any credit line"""
# Out:
# 'Number of days since last missed payment on any credit line'

# %%
TRAIN["form_field28"].isnull().sum()
# Out:
# 355

# %%
TRAIN["form_field28"].value_counts()
# Out:
# 60772.0    15407
# 0.0        11546
# 60.0        8973
# 122.0       2356
# 182.0       1430
#            ...
# 5414.0         1
# 6022.0         1
# 7056.0         1
# 5780.0         1
# 6510.0         1
# Name: form_field28, Length: 95, dtype: int64

# %%
new_train["form_field28"]= TRAIN["form_field28"]
median_28 = new_train["form_field28"].median()
new_train["form_field28"] = new_train["form_field28"].fillna(median_28) ##fills the NaN values with the median score
new_train.head()
# Out:
#    form_field47  form_field14  form_field28
# 0             0      96375139          60.0
# 1             0      28141427         304.0
# 2             0      16576457          60.0
# 3             0      48187375          60.0
# 4             0      28141427          60.0

# %%
new_train.isnull().sum() #checks null values in new_train dataframe
print("median score for form_field 28 is:", median_28)
# Out:
# median score for form_field 28 is: 486.0

# %%
import matplotlib.pyplot as plt
import missingno as msn
plt.figure(figsize=(30,25))
msn.matrix(TRAIN)

# %% [markdown]
# form_field3 	Severity of default by the borrower on any loan(s).
#
# form_field10 	otal amount of credit available on accepted credit lines (in NGN)
#
# form_field4 	Severity of default by the borrower on auto loan(s).
#
# form_field34 	Number of active credit lines over the last 6 months on which the borrower has missed 1 payment
#
# form_field5 	Severity of default by the borrower on education loan(s)
#
# form_field29 	 Tenure of the oldest credit line (in days)
#
# form_field20 	Number of active credit lines on which at least 75% credit limit is utilizedby the borrower
#
# form_field49 	Undefined Variable
#
# form_field38 	Number of credit lines activated in the last 2 years
#
# form_field28 	Number of days since last missed payment on any credit line

# %%
types_cols = ["form_field10","form_field3",
              "form_field4", "form_field34", "form_field5","form_field29",
              "form_field20", 	"form_field49" ,"form_field38", 	"form_field28"]
"""all dtypes are float64"""
TRAIN[types_cols].dtypes #checks datatypes for these specific columns
# Out:
# form_field10    float64
# form_field3     float64
# form_field4     float64
# form_field34    float64
# form_field5     float64
# form_field29    float64
# form_field20    float64
# form_field49    float64
# form_field38    float64
# form_field28    float64
# dtype: object

# %%
new_train.head()
# Out:
#    form_field47  form_field14  form_field28
# 0             0      96375139          60.0
# 1             0      28141427         304.0
# 2             0      16576457          60.0
# 3             0      48187375          60.0
# 4             0      28141427          60.0

# %%
new_train
new_train[types_cols]= TRAIN[types_cols] 
new_train[new_train.isna().any(axis = 1)]
# Out:
#        form_field47  form_field14  form_field28  form_field10  form_field3  \
# 156               0      17347455           NaN           NaN          NaN
# 160               0      11564970           NaN           NaN          NaN
# 270               1      15419960           NaN           NaN          NaN
# 519               0      96375139           NaN           NaN          NaN
# 610               0      13877964           NaN           NaN          NaN
# ...             ...           ...           ...           ...          ...
# 55767             0      11564970           NaN           NaN          NaN
# 55790             0      21973443           NaN           NaN          NaN
# 55809             0      34694910           NaN           NaN          NaN
# 55814             0      28141427           NaN           NaN          NaN
# 55845             0      11564970           NaN           NaN          NaN
#
# ...

# %%
new_train.loc[int(156)]
# Out:
# form_field47           0.0
# form_field14    17347455.0
# form_field28           NaN
# form_field10           NaN
# form_field3            NaN
# form_field4            NaN
# form_field34           NaN
# form_field5            NaN
# form_field29           NaN
# form_field20           NaN
# form_field49           NaN
# form_field38           NaN
# Name: 156, dtype: float64

# %%
new_train.isnull().sum()
# Out:
# form_field47      0
# form_field14      0
# form_field28    355
# form_field10    355
# form_field3     355
# form_field4     355
# form_field34    355
# form_field5     355
# form_field29    355
# form_field20    355
# form_field49    355
# form_field38    355
# dtype: int64

# %%
#new_train["form_field28"]= TRAIN["form_field28"]
median_28 = new_train["form_field28"].median()
new_train["form_field28"] = new_train["form_field28"].fillna(median_28) ##fills the NaN values with the median score
new_train.isnull().sum()
# Out:
# form_field47      0
# form_field14      0
# form_field28      0
# form_field10    355
# form_field3     355
# form_field4     355
# form_field34    355
# form_field5     355
# form_field29    355
# form_field20    355
# form_field49    355
# form_field38    355
# dtype: int64

# %%
#median values for form field 10
median_10 = new_train["form_field10"].median()
new_train["form_field10"] = new_train["form_field10"].fillna(median_10) ##fills the NaN values with the median score
new_train.isnull().sum()
# Out:
# form_field47      0
# form_field14      0
# form_field28      0
# form_field10      0
# form_field3     355
# form_field4     355
# form_field34    355
# form_field5     355
# form_field29    355
# form_field20    355
# form_field49    355
# form_field38    355
# dtype: int64

# %%
#median values for form field 3
median_3 = new_train["form_field3"].median()
new_train["form_field3"] = new_train["form_field3"].fillna(median_3) ##fills the NaN values with the median score
new_train.isnull().sum()
# Out:
# form_field47      0
# form_field14      0
# form_field28      0
# form_field10      0
# form_field3       0
# form_field4     355
# form_field34    355
# form_field5     355
# form_field29    355
# form_field20    355
# form_field49    355
# form_field38    355
# dtype: int64

# %%
#function to fill NaN columns
def fill_NaN(column_to_fill):
    
    
    median_value = new_train[column_to_fill].median()
    new_train[column_to_fill] = new_train[column_to_fill].fillna(median_value) ##fills the NaN values with the median score
    
    return new_train.isnull().sum()

# %%
fill_NaN("form_field4")
# Out:
# form_field47      0
# form_field14      0
# form_field28      0
# form_field10      0
# form_field3       0
# form_field4       0
# form_field34    355
# form_field5     355
# form_field29    355
# form_field20    355
# form_field49    355
# form_field38    355
# dtype: int64

# %%
fill_NaN("form_field34")
# Out:
# form_field47      0
# form_field14      0
# form_field28      0
# form_field10      0
# form_field3       0
# form_field4       0
# form_field34      0
# form_field5     355
# form_field29    355
# form_field20    355
# form_field49    355
# form_field38    355
# dtype: int64

# %%
fill_NaN("form_field5") #fills column FORM_FIELD5 null values with median values
# Out:
# form_field47      0
# form_field14      0
# form_field28      0
# form_field10      0
# form_field3       0
# form_field4       0
# form_field34      0
# form_field5       0
# form_field29    355
# form_field20    355
# form_field49    355
# form_field38    355
# dtype: int64

# %%
fill_NaN("form_field29") #fills column FORM_FIELD29 null values with median values
# Out:
# form_field47      0
# form_field14      0
# form_field28      0
# form_field10      0
# form_field3       0
# form_field4       0
# form_field34      0
# form_field5       0
# form_field29      0
# form_field20    355
# form_field49    355
# form_field38    355
# dtype: int64

# %%
fill_NaN("form_field20") #fills column FORM_FIELD20 null values with median values
# Out:
# form_field47      0
# form_field14      0
# form_field28      0
# form_field10      0
# form_field3       0
# form_field4       0
# form_field34      0
# form_field5       0
# form_field29      0
# form_field20      0
# form_field49    355
# form_field38    355
# dtype: int64

# %%
fill_NaN("form_field49") #fills column FORM_FIELD49 null values with median values
# Out:
# form_field47      0
# form_field14      0
# form_field28      0
# form_field10      0
# form_field3       0
# form_field4       0
# form_field34      0
# form_field5       0
# form_field29      0
# form_field20      0
# form_field49      0
# form_field38    355
# dtype: int64

# %%
fill_NaN("form_field38") #fills column FORM_FIELD38 null values with median values
# Out:
# form_field47    0
# form_field14    0
# form_field28    0
# form_field10    0
# form_field3     0
# form_field4     0
# form_field34    0
# form_field5     0
# form_field29    0
# form_field20    0
# form_field49    0
# form_field38    0
# dtype: int64

# %%
#check new_train DataFrame
new_train
# Out:
#        form_field47  form_field14  form_field28  form_field10  form_field3  \
# 0                 0      96375139          60.0    11333126.0       1.6560
# 1                 0      28141427         304.0     2533168.0       0.2342
# 2                 0      16576457          60.0     1079864.0       3.1510
# 3                 0      48187375          60.0     3621979.0       0.5050
# 4                 0      28141427          60.0      361770.0       1.1010
# ...             ...           ...           ...           ...          ...
# 55995             1      48187375       60772.0    19910965.0       0.0000
# 55996             1      16576457          60.0     1849306.0       0.6252
# 55997             1      21973443        2980.0      704090.0       0.0000
# 55998             0      38549900          60.0     3458599.0       2.0916
# 55999             0      21973443        1278.0     5430440.0       0.0000
#
# ...

# %%
#check original train data
TRAIN
# Out:
#        form_field1  form_field2  form_field3  form_field4  form_field5  \
# 0           3436.0      0.28505       1.6560       0.0000        0.000
# 1           3456.0      0.67400       0.2342       0.0000        0.000
# 2           3276.0      0.53845       3.1510       0.0000        6.282
# 3           3372.0      0.17005       0.5050       0.0000        0.000
# 4           3370.0      0.77270       1.1010       0.0000        0.000
# ...            ...          ...          ...          ...          ...
# 55995       3740.0      0.01730       0.0000       0.0000        0.000
# 55996       3360.0      2.01145       0.6252       0.0000        0.000
# 55997       3500.0      0.76640       0.0000       0.0000        0.000
# 55998       3280.0      0.05235       2.0916       2.2212        0.000
# 55999       3522.0      0.46930       0.0000       0.0000        0.000
#
#        form_field6  form_field7  form_field8  form_field9  form_field10  ...  \
# ...

# %%
#check nan values dataframe
TRAIN.drop(columns = ["form_field15","form_field48"], inplace = True),nan_val
# Out:
# (None,                 non_nan  nan_val
#  form_field40      12271    43729
#  form_field31      16592    39408
#  form_field41      17771    38229
#  form_field11      24579    31421
#  form_field45      24683    31317
#  form_field23      27877    28123
#  form_field30      30491    25509
#  form_field35      32852    23148
#  form_field15      33525    22475
#  form_field48      35111    20889
#  form_field22      35600    20400
#  form_field46      40096    15904
#  form_field21      40146    15854
#  form_field8       42640    13360
#  form_field6       42640    13360
#  form_field24      42703    13297
#  form_field16      42964    13036
#  form_field17      44849    11151
#  form_field50      44944    11056
#  form_field18      45598    10402
#  form_field12      46105     9895
#  form_field27      46701     9299
#  form_field9       47992     8008
#  form_field26      48562     7438
#  form_field13      50111     5889
#  form_field32      50550     5450
# ...

# %%
TRAIN.shape, new_train.shape
# Out:
# ((56000, 42), (56000, 12))

# %%
new_train.columns,nan_val
# Out:
# (Index(['form_field47', 'form_field14', 'form_field28', 'form_field10',
#         'form_field3', 'form_field4', 'form_field34', 'form_field5',
#         'form_field29', 'form_field20', 'form_field49', 'form_field38'],
#        dtype='object'),                 non_nan  nan_val
#  form_field40      12271    43729
#  form_field31      16592    39408
#  form_field41      17771    38229
#  form_field11      24579    31421
#  form_field45      24683    31317
#  form_field23      27877    28123
#  form_field30      30491    25509
#  form_field35      32852    23148
#  form_field15      33525    22475
#  form_field48      35111    20889
#  form_field22      35600    20400
#  form_field46      40096    15904
#  form_field21      40146    15854
#  form_field8       42640    13360
#  form_field6       42640    13360
#  form_field24      42703    13297
#  form_field16      42964    13036
#  form_field17      44849    11151
#  form_field50      44944    11056
#  form_field18      45598    10402
# ...

# %% [markdown]
# #imputing data FOR form_field43, form_field33, form_field42, form_field36,form_field1,
# form_field2,form_field39,form_field7,form_field44

# %%
#form_field43 data analysis
#form_field43:OTHER-Number of credit lines on which the borrower has
#never missed a payment in the last 2 years,
#yet considered as high-risk loans based on the market prediction of the economic scenario
def fill_NaN_col(column_to_fill):
    
    new_train[column_to_fill] = TRAIN[column_to_fill]
    median_value = new_train[column_to_fill].median()
    new_train[column_to_fill] = new_train[column_to_fill].fillna(median_value) ##fills the NaN values with the median score
    
    return new_train.shape
    return new_train.isnull().sum()
      #function to fill null values in TRAIN datasets and add the column to new_train dataset

# %%
fill_NaN_col("form_field43")
# Out:
# (56000, 13)

# %%
new_train["form_field43"]
# Out:
# 0         2.02
# 1         8.08
# 2        18.18
# 3         2.02
# 4        12.12
#          ...
# 55995     9.09
# 55996    30.30
# 55997     3.03
# 55998     0.00
# 55999    13.13
# Name: form_field43, Length: 56000, dtype: float64

# %%
import seaborn as sns
import matplotlib.pyplot as plt
plt.figure(figsize = (30,15))
sns.countplot(new_train["form_field43"])

#majority of applicants missed payments in the last 2 years

# %%
#form field42: OTHER-Financial stress index of the borrower. 
#This index is a function of collection trades,
#bankruptcies files, tax liens invoked, etc.
fill_NaN_col("form_field42")
# Out:
# (56000, 14)

# %%
new_train["form_field42"]
# Out:
# 0        0.392854
# 1        0.314281
# 2        0.162965
# 3        0.488884
# 4        0.275000
#            ...
# 55995    0.000000
# 55996    0.297913
# 55997    0.550000
# 55998    0.942854
# 55999    0.000000
# Name: form_field42, Length: 56000, dtype: float64

# %%
new_train.shape
# Out:
# (56000, 14)

# %%
#form field33: TIME FEATURE-Sum of tenures (in months) of active credit cards
fill_NaN_col("form_field33")
# Out:
# (56000, 15)

# %%
new_train["form_field33"].value_counts()
# Out:
# 0.1666      2338
# 7.8334      1548
# 0.6666      1141
# 0.3334      1088
# 0.5000      1073
#             ...
# 111.5000       1
# 118.3334       1
# 95.0000        1
# 67.8334        1
# 119.8334       1
# Name: form_field33, Length: 554, dtype: int64

# %%
#form_field36: number of active credit lines
fill_NaN_col("form_field36")
# Out:
# (56000, 16)

# %%
new_train.head(20)
# Out:
#     form_field47  form_field14  form_field28  form_field10  form_field3  \
# 0              0      96375139          60.0    11333126.0       1.6560
# 1              0      28141427         304.0     2533168.0       0.2342
# 2              0      16576457          60.0     1079864.0       3.1510
# 3              0      48187375          60.0     3621979.0       0.5050
# 4              0      28141427          60.0      361770.0       1.1010
# 5              1      16576457        3772.0    32902009.0       0.0000
# 6              0      21973443         426.0      580388.0       0.3132
# 7              0      11564970         548.0      326760.0       0.0570
# 8              0      11564970         182.0     1557167.0       0.5586
# 9              0      11564970         182.0           0.0       0.1562
# 10             0      16576457         670.0     2546783.0       0.0000
# 11             0      38549900        4624.0     2509828.0       0.0000
# ...

# %%
#RISK SCORING FACTOR
#form_field1: Customer Credit worthiness score based on historical data
fill_NaN_col("form_field1")
# Out:
# (56000, 17)

# %%
new_train["form_field1"].value_counts()
# Out:
# 3484.0    2753
# 3472.0     318
# 3488.0     311
# 3518.0     304
# 3502.0     293
#           ...
# 3020.0       1
# 3008.0       1
# 3000.0       1
# 3016.0       1
# 3046.0       1
# Name: form_field1, Length: 449, dtype: int64

# %%
TRAIN["form_field2"].dtypes,TRAIN["form_field39"].dtypes,TRAIN["form_field7"].dtypes,TRAIN["form_field44"].dtypes
# Out:
# (dtype('float64'), dtype('float64'), dtype('float64'), dtype('float64'))

# %%
#form_field2:
#RISK SCORING-A score that measures the number and riskiness of credit enquiries made by a borrower
fill_NaN_col("form_field2")
# Out:
# (56000, 18)

# %%
new_train.head(20)
# Out:
#     form_field47  form_field14  form_field28  form_field10  form_field3  \
# 0              0      96375139          60.0    11333126.0       1.6560
# 1              0      28141427         304.0     2533168.0       0.2342
# 2              0      16576457          60.0     1079864.0       3.1510
# 3              0      48187375          60.0     3621979.0       0.5050
# 4              0      28141427          60.0      361770.0       1.1010
# 5              1      16576457        3772.0    32902009.0       0.0000
# 6              0      21973443         426.0      580388.0       0.3132
# 7              0      11564970         548.0      326760.0       0.0570
# 8              0      11564970         182.0     1557167.0       0.5586
# 9              0      11564970         182.0           0.0       0.1562
# 10             0      16576457         670.0     2546783.0       0.0000
# 11             0      38549900        4624.0     2509828.0       0.0000
# ...

# %%
#form_field39:TIME FEATURE Number of credit lines on which the borrower has current delinquency
fill_NaN_col("form_field39")
# Out:
# (56000, 19)

# %%
#form_field7:CREDIT FEATURES
#Maximum of credit available on customer’s active credit lines (in NGN)
fill_NaN_col("form_field7")
# Out:
# (56000, 20)

# %%
new_train.head()
# Out:
#    form_field47  form_field14  form_field28  form_field10  form_field3  \
# 0             0      96375139          60.0    11333126.0       1.6560
# 1             0      28141427         304.0     2533168.0       0.2342
# 2             0      16576457          60.0     1079864.0       3.1510
# 3             0      48187375          60.0     3621979.0       0.5050
# 4             0      28141427          60.0      361770.0       1.1010
#
#    form_field4  form_field34  form_field5  form_field29  form_field20  \
# 0          0.0           2.0        0.000       17064.0           3.0
# 1          0.0           0.0        0.000       13413.0           2.0
# 2          0.0           0.0        6.282       15696.0           0.0
# 3          0.0           1.0        0.000       11679.0           1.0
# 4          0.0           0.0        0.000       19437.0           3.0
#
#    form_field49  form_field38  form_field43  form_field42  form_field33  \
# ...

# %%
#form_field44
#Ratio of the maximum amount due on all active..
#..credit lines and the sum of amounts due on all active credit lines
fill_NaN_col("form_field44")
# Out:
# (56000, 21)

# %%
#COMPARE DATAFRAMES
new_train.head()
# Out:
#    form_field47  form_field14  form_field28  form_field10  form_field3  \
# 0             0      96375139          60.0    11333126.0       1.6560
# 1             0      28141427         304.0     2533168.0       0.2342
# 2             0      16576457          60.0     1079864.0       3.1510
# 3             0      48187375          60.0     3621979.0       0.5050
# 4             0      28141427          60.0      361770.0       1.1010
#
#    form_field4  form_field34  form_field5  form_field29  form_field20  ...  \
# 0          0.0           2.0        0.000       17064.0           3.0  ...
# 1          0.0           0.0        0.000       13413.0           2.0  ...
# 2          0.0           0.0        6.282       15696.0           0.0  ...
# 3          0.0           1.0        0.000       11679.0           1.0  ...
# 4          0.0           0.0        0.000       19437.0           3.0  ...
#
#    form_field38  form_field43  form_field42  form_field33  form_field36  \
# ...

# %%
new_train.columns,nan_val
# Out:
# (Index(['form_field47', 'form_field14', 'form_field28', 'form_field10',
#         'form_field3', 'form_field4', 'form_field34', 'form_field5',
#         'form_field29', 'form_field20', 'form_field49', 'form_field38',
#         'form_field43', 'form_field42', 'form_field33', 'form_field36',
#         'form_field1', 'form_field2', 'form_field39', 'form_field7',
#         'form_field44'],
#        dtype='object'),                 non_nan  nan_val
#  form_field40      12271    43729
#  form_field31      16592    39408
#  form_field41      17771    38229
#  form_field11      24579    31421
#  form_field45      24683    31317
#  form_field23      27877    28123
#  form_field30      30491    25509
#  form_field35      32852    23148
#  form_field15      33525    22475
#  form_field48      35111    20889
#  form_field22      35600    20400
#  form_field46      40096    15904
#  form_field21      40146    15854
#  form_field8       42640    13360
#  form_field6       42640    13360
# ...

# %% [markdown]
# imputing values for form_field12
#  form_field27
#  form_field9
#  form_field26
#  form_field13
#  form_field32
#  form_field25
#  form_field37

# %%
print(TRAIN["form_field27"].dtypes)
print(TRAIN["form_field9"].dtypes)
print(TRAIN["form_field26"].dtypes)
print(TRAIN["form_field13"].dtypes)
print(TRAIN["form_field32"].dtypes)
print(TRAIN["form_field25"].dtypes)
print(TRAIN["form_field37"].dtypes)
# Out:
# float64
# float64
# float64
# float64
# float64
# float64
# float64

# %%
#form_field27: CREDIT CARD FEATURE
#Tenure of oldest revolving credit card among all active revolving credit cards (in days)
fill_NaN_col("form_field27")
# Out:
# (56000, 22)

# %%
#form_field9:CREDIT FEATURES
#Sum of available credit on credit cards that the borrower has missed 1 payment (in NGN)
fill_NaN_col("form_field9")
# Out:
# (56000, 23)

# %%
new_train["form_field9"].value_counts()
# Out:
# 5506295.0     8008
# 115533.0       846
# 192944.0       678
# 385499.0       388
# 96472.0        283
#               ...
# 34972267.0       1
# 25182304.0       1
# 21317200.0       1
# 1778897.0        1
# 8859086.0        1
# Name: form_field9, Length: 22651, dtype: int64

# %%
#form_field26: CREDITCARDFEATTenure of oldest credit card among all active credit cards (in days)
fill_NaN_col("form_field26")
# Out:
# (56000, 24)

# %%
fill_NaN_col("form_field13") #credit card feat form_field13:
#Annual amount paid towards all credit cards during the previous year (in NGN)

fill_NaN_col("form_field32")# TIME FEAT form_field32: Sum of tenures (in months) of active credit cards

fill_NaN_col("form_field25") #Average tenure of active revolving credit cards (in days)

fill_NaN_col("form_field37") # Number of credit cards with an active tenure of at least 2 years
# Out:
# (56000, 28)

# %%
new_train.head(20)
# Out:
#     form_field47  form_field14  form_field28  form_field10  form_field3  \
# 0              0      96375139          60.0    11333126.0       1.6560
# 1              0      28141427         304.0     2533168.0       0.2342
# 2              0      16576457          60.0     1079864.0       3.1510
# 3              0      48187375          60.0     3621979.0       0.5050
# 4              0      28141427          60.0      361770.0       1.1010
# 5              1      16576457        3772.0    32902009.0       0.0000
# 6              0      21973443         426.0      580388.0       0.3132
# 7              0      11564970         548.0      326760.0       0.0570
# 8              0      11564970         182.0     1557167.0       0.5586
# 9              0      11564970         182.0           0.0       0.1562
# 10             0      16576457         670.0     2546783.0       0.0000
# 11             0      38549900        4624.0     2509828.0       0.0000
# ...

# %%
TRAIN.columns
# Out:
# Index(['form_field1', 'form_field2', 'form_field3', 'form_field4',
#        'form_field5', 'form_field6', 'form_field7', 'form_field8',
#        'form_field9', 'form_field10', 'form_field12', 'form_field13',
#        'form_field14', 'form_field16', 'form_field17', 'form_field18',
#        'form_field19', 'form_field20', 'form_field21', 'form_field22',
#        'form_field24', 'form_field25', 'form_field26', 'form_field27',
#        'form_field28', 'form_field29', 'form_field32', 'form_field33',
#        'form_field34', 'form_field36', 'form_field37', 'form_field38',
#        'form_field39', 'form_field40', 'form_field42', 'form_field43',
#        'form_field44', 'form_field46', 'form_field47', 'form_field49',
#        'form_field50', 'default_status'],
#       dtype='object')

# %%
#check NaN VALUES dataframe again
new_train.columns,nan_val
# Out:
# (Index(['form_field47', 'form_field14', 'form_field28', 'form_field10',
#         'form_field3', 'form_field4', 'form_field34', 'form_field5',
#         'form_field29', 'form_field20', 'form_field49', 'form_field38',
#         'form_field43', 'form_field42', 'form_field33', 'form_field36',
#         'form_field1', 'form_field2', 'form_field39', 'form_field7',
#         'form_field44', 'form_field27', 'form_field9', 'form_field26',
#         'form_field13', 'form_field32', 'form_field25', 'form_field37'],
#        dtype='object'),                 non_nan  nan_val
#  form_field40      12271    43729
#  form_field31      16592    39408
#  form_field41      17771    38229
#  form_field11      24579    31421
#  form_field45      24683    31317
#  form_field23      27877    28123
#  form_field30      30491    25509
#  form_field35      32852    23148
#  form_field15      33525    22475
#  form_field48      35111    20889
#  form_field22      35600    20400
# ...

# %% [markdown]
# imputing values for
#  form_field22
#  form_field46
#  form_field21
#  form_field8
#  form_field6
#  form_field24
#  form_field16
#  form_field17
#  form_field50
#  form_field18
#  form_field12

# %%
#check datatypes
print("22",TRAIN["form_field22"].dtype)     
print("46",TRAIN["form_field46"].dtype)      
print("21",TRAIN["form_field21"].dtype)      
print("8",TRAIN["form_field8"].dtype)       
print("6",TRAIN["form_field6"].dtype)       
print("24",TRAIN["form_field24"].dtype)      
print("16",TRAIN["form_field16"].dtype)      
print("17", TRAIN["form_field17"].dtype)      
print("50", TRAIN["form_field50"].dtype)      
print("18", TRAIN["form_field18"].dtype)      
print("12",TRAIN["form_field12"].dtype)  

"""all columns are float and median can be easily computed"""
# Out:
# 22 float64
# 46 float64
# 21 float64
# 8 float64
# 6 float64
# 24 float64
# 16 float64
# 17 float64
# 50 float64
# 18 float64
# 12 float64
# 'all columns are float and median can be easily computed'

# %%
#form_field22:CREDIT CARD FEAT
#Average utilization of line on all active credit lines activated in last 2 years (%)
TRAIN["form_field22"].head(15)
# Out:
# 0           NaN
# 1     11385.240
# 2           NaN
# 3      8580.000
# 4      8360.190
# 5           NaN
# 6           NaN
# 7      8267.655
# 8           NaN
# 9           NaN
# 10     6885.000
# 11    12198.705
# 12     3666.000
# 13          NaN
# 14          NaN
# Name: form_field22, dtype: float64

# %%
#fill null values in form_field22 column
fill_NaN_col("form_field22")
# Out:
# (56000, 29)

# %%
fill_NaN_col("form_field46")  ##Number of auto loans on which the borrower has missed 2 payments     
fill_NaN_col("form_field21")  ##Average utilization of active revolving credit card loans (%)
fill_NaN_col("form_field8")   ##Maximum of credit available on all active credit cards that is automatically renewed as debts are paid off on the customer’s cards    
fill_NaN_col("form_field6")   ## Minimum of credit available on all credit cards that is automatically renewed as debts are paid off on the customer’s cards    
fill_NaN_col("form_field24")  ## Average utilization of line on credit cards on which the borrower has missed 1 payment during the last 6 months    
fill_NaN_col("form_field16")  ##Number of active credit card that is automatically renewed as debts are paid off on which full credit limit is utilized by the borrower 
fill_NaN_col("form_field17")  ##Number of active credit cards on which full credit limit is utilized by the borrower 
fill_NaN_col("form_field50")  ##The amount of dues collected post-default where the due amount was more than 500      
fill_NaN_col("form_field18")  ##Number of active credit lines on which full credit limit is utilized by the borrower     
fill_NaN_col("form_field12")  ##Sum of the amount due on active credit cards
# Out:
# (56000, 39)

# %%
new_train
# Out:
#        form_field47  form_field14  form_field28  form_field10  form_field3  \
# 0                 0      96375139          60.0    11333126.0       1.6560
# 1                 0      28141427         304.0     2533168.0       0.2342
# 2                 0      16576457          60.0     1079864.0       3.1510
# 3                 0      48187375          60.0     3621979.0       0.5050
# 4                 0      28141427          60.0      361770.0       1.1010
# ...             ...           ...           ...           ...          ...
# 55995             1      48187375       60772.0    19910965.0       0.0000
# 55996             1      16576457          60.0     1849306.0       0.6252
# 55997             1      21973443        2980.0      704090.0       0.0000
# 55998             0      38549900          60.0     3458599.0       2.0916
# 55999             0      21973443        1278.0     5430440.0       0.0000
#
# ...

# %%
TRAIN
# Out:
#        form_field1  form_field2  form_field3  form_field4  form_field5  \
# 0           3436.0      0.28505       1.6560       0.0000        0.000
# 1           3456.0      0.67400       0.2342       0.0000        0.000
# 2           3276.0      0.53845       3.1510       0.0000        6.282
# 3           3372.0      0.17005       0.5050       0.0000        0.000
# 4           3370.0      0.77270       1.1010       0.0000        0.000
# ...            ...          ...          ...          ...          ...
# 55995       3740.0      0.01730       0.0000       0.0000        0.000
# 55996       3360.0      2.01145       0.6252       0.0000        0.000
# 55997       3500.0      0.76640       0.0000       0.0000        0.000
# 55998       3280.0      0.05235       2.0916       2.2212        0.000
# 55999       3522.0      0.46930       0.0000       0.0000        0.000
#
#        form_field6  form_field7  form_field8  form_field9  form_field10  ...  \
# ...

# %%
corr_matrix = TRAIN.corr()
corr_matrix["default_status"].sort_values(ascending=False)
# Out:
# default_status    1.000000
# form_field42      0.329039
# form_field21      0.325634
# form_field22      0.322421
# form_field16      0.275836
# form_field17      0.269507
# form_field18      0.265692
# form_field2       0.226313
# form_field46      0.196138
# form_field3       0.193603
# form_field36      0.167306
# form_field40      0.164199
# form_field49      0.152407
# form_field38      0.151966
# form_field34      0.151109
# form_field4       0.147548
# form_field39      0.145949
# form_field19      0.134433
# form_field20      0.127612
# form_field5       0.088912
# form_field24      0.064261
# form_field14      0.008272
# form_field12     -0.042858
# form_field50     -0.049732
# form_field44     -0.066595
# form_field13     -0.089314
# form_field7      -0.113481
# form_field33     -0.140934
# form_field43     -0.165155
# form_field6      -0.165438
# form_field10     -0.170323
# form_field9      -0.206441
# form_field29     -0.209252
# form_field37     -0.213527
# ...

# %%
import missingno as msn
msn.matrix(TRAIN)  #checks columns with missing values that depends on one another in
                   #original dataset

# %%
#make copys of new_train dataset
new_train.columns
# Out:
# Index(['form_field47', 'form_field14', 'form_field28', 'form_field10',
#        'form_field3', 'form_field4', 'form_field34', 'form_field5',
#        'form_field29', 'form_field20', 'form_field49', 'form_field38',
#        'form_field43', 'form_field42', 'form_field33', 'form_field36',
#        'form_field1', 'form_field2', 'form_field39', 'form_field7',
#        'form_field44', 'form_field27', 'form_field9', 'form_field26',
#        'form_field13', 'form_field32', 'form_field25', 'form_field37',
#        'form_field22', 'form_field46', 'form_field21', 'form_field8',
#        'form_field6', 'form_field24', 'form_field16', 'form_field17',
#        'form_field50', 'form_field18', 'form_field12'],
#       dtype='object')

# %%
colss =["form_field32","form_field33","form_field29","form_field27","form_field25",
        "form_field26"]
new_train[colss]
# Out:
#        form_field32  form_field33  form_field29  form_field27  form_field25  \
# 0            1052.0        8.0000       17064.0       11376.0        4000.5
# 1            2554.0       17.5000       13413.0        8942.0        4161.0
# 2              70.0        0.6666       15696.0        3164.0        1597.5
# 3             522.0        7.8334       11679.0        2676.0        1701.0
# 4             272.0        1.0000       19437.0        2190.0        1551.0
# ...             ...           ...           ...           ...           ...
# 55995         864.0       21.6666       15969.0        4866.0        2815.5
# 55996         242.0       14.6666       11589.0        3650.0        1840.5
# 55997         232.0       22.3334       12135.0        2616.0        1059.0
# 55998         104.0       57.5000       25641.0        5110.0        2373.0
# 55999        1410.0        0.8334       22083.0       11010.0        5361.0
#
#        form_field26
# 0           17064.0
# ...

# %%
#copy new_train dataframe to keep it intact
new_train1 = new_train.copy()
new_train2 = new_train.copy()

# %%
new_train1
# Out:
#        form_field47  form_field14  form_field28  form_field10  form_field3  \
# 0                 0      96375139          60.0    11333126.0       1.6560
# 1                 0      28141427         304.0     2533168.0       0.2342
# 2                 0      16576457          60.0     1079864.0       3.1510
# 3                 0      48187375          60.0     3621979.0       0.5050
# 4                 0      28141427          60.0      361770.0       1.1010
# ...             ...           ...           ...           ...          ...
# 55995             1      48187375       60772.0    19910965.0       0.0000
# 55996             1      16576457          60.0     1849306.0       0.6252
# 55997             1      21973443        2980.0      704090.0       0.0000
# 55998             0      38549900          60.0     3458599.0       2.0916
# 55999             0      21973443        1278.0     5430440.0       0.0000
#
# ...

# %%
#convert form_field32 column from months to days
new_train1["form_field32"]= new_train1["form_field32"]*30
new_train1[colss]
# Out:
#        form_field32  form_field33  form_field29  form_field27  form_field25  \
# 0           31560.0        8.0000       17064.0       11376.0        4000.5
# 1           76620.0       17.5000       13413.0        8942.0        4161.0
# 2            2100.0        0.6666       15696.0        3164.0        1597.5
# 3           15660.0        7.8334       11679.0        2676.0        1701.0
# 4            8160.0        1.0000       19437.0        2190.0        1551.0
# ...             ...           ...           ...           ...           ...
# 55995       25920.0       21.6666       15969.0        4866.0        2815.5
# 55996        7260.0       14.6666       11589.0        3650.0        1840.5
# 55997        6960.0       22.3334       12135.0        2616.0        1059.0
# 55998        3120.0       57.5000       25641.0        5110.0        2373.0
# 55999       42300.0        0.8334       22083.0       11010.0        5361.0
#
#        form_field26
# 0           17064.0
# ...

# %%
new_train1["form_field17"].value_counts()
# Out:
# 0.0     48010
# 1.0      5653
# 2.0      1488
# 3.0       489
# 4.0       193
# 5.0        87
# 6.0        29
# 7.0        23
# 8.0        11
# 9.0         6
# 10.0        4
# 11.0        3
# 13.0        2
# 21.0        1
# 16.0        1
# Name: form_field17, dtype: int64

# %%
new_train1["form_field18"].value_counts()
# Out:
# 0.0     47667
# 1.0      5909
# 2.0      1546
# 3.0       508
# 4.0       200
# 5.0        85
# 6.0        33
# 7.0        24
# 8.0        11
# 9.0         6
# 10.0        4
# 13.0        2
# 11.0        2
# 12.0        1
# 21.0        1
# 16.0        1
# Name: form_field18, dtype: int64

# %%
"""drop columns with similar names and more NaN value"""
new_train1.drop(columns = ["form_field17","form_field33"], inplace = True)

# %%
new_train1.shape, new_train.shape, new_train2.shape
# Out:
# ((56000, 37), (56000, 39), (56000, 39))

# %%
new_train1
# Out:
#        form_field47  form_field14  form_field28  form_field10  form_field3  \
# 0                 0      96375139          60.0    11333126.0       1.6560
# 1                 0      28141427         304.0     2533168.0       0.2342
# 2                 0      16576457          60.0     1079864.0       3.1510
# 3                 0      48187375          60.0     3621979.0       0.5050
# 4                 0      28141427          60.0      361770.0       1.1010
# ...             ...           ...           ...           ...          ...
# 55995             1      48187375       60772.0    19910965.0       0.0000
# 55996             1      16576457          60.0     1849306.0       0.6252
# 55997             1      21973443        2980.0      704090.0       0.0000
# 55998             0      38549900          60.0     3458599.0       2.0916
# 55999             0      21973443        1278.0     5430440.0       0.0000
#
# ...

# %% [markdown]
# PREPROCESSING of new_train1

# %%
new_train1["form_field32"]
# Out:
# 0        31560.0
# 1        76620.0
# 2         2100.0
# 3        15660.0
# 4         8160.0
#           ...
# 55995    25920.0
# 55996     7260.0
# 55997     6960.0
# 55998     3120.0
# 55999    42300.0
# Name: form_field32, Length: 56000, dtype: float64

# %%
#scale the dataset with MinMax scaler
new_train1_scale = new_train1.copy()
#create new dataframe with new_train1_scale withhout form_field47 column
df_47 = new_train1_scale.drop(columns =["form_field47"])
from sklearn.preprocessing import Normalizer
scaler = Normalizer()
new_train1_scaled = pd.DataFrame(scaler.fit_transform(new_train1_scale.drop(columns=["form_field47"])),
                                                      columns = df_47.columns)
new_train1_scaled
# Out:
#        form_field14  form_field28  form_field10   form_field3   form_field4  \
# 0          0.982779  6.118462e-07      0.115569  1.688695e-08  0.000000e+00
# 1          0.936902  1.012095e-05      0.084336  7.797130e-09  0.000000e+00
# 2          0.992062  3.590860e-06      0.064627  1.885800e-07  0.000000e+00
# 3          0.991398  1.234428e-06      0.074518  1.038977e-08  0.000000e+00
# 4          0.998234  2.128323e-06      0.012833  3.905474e-08  0.000000e+00
# ...             ...           ...           ...           ...           ...
# 55995      0.798688  1.007274e-03      0.330017  0.000000e+00  0.000000e+00
# 55996      0.938947  3.398603e-06      0.104751  3.541345e-08  0.000000e+00
# 55997      0.938201  1.272371e-04      0.030063  0.000000e+00  0.000000e+00
# 55998      0.991289  1.542866e-06      0.088936  5.378431e-08  5.711690e-08
# 55999      0.758456  4.411263e-05      0.187442  0.000000e+00  0.000000e+00
#
# ...

# %%
new_train1_scaled["form_field47"]= new_train1["form_field47"] #adds form_field 47 column to scaled dataframe

# %%
new_train1_scaled
# Out:
#        form_field14  form_field28  form_field10   form_field3   form_field4  \
# 0          0.982779  6.118462e-07      0.115569  1.688695e-08  0.000000e+00
# 1          0.936902  1.012095e-05      0.084336  7.797130e-09  0.000000e+00
# 2          0.992062  3.590860e-06      0.064627  1.885800e-07  0.000000e+00
# 3          0.991398  1.234428e-06      0.074518  1.038977e-08  0.000000e+00
# 4          0.998234  2.128323e-06      0.012833  3.905474e-08  0.000000e+00
# ...             ...           ...           ...           ...           ...
# 55995      0.798688  1.007274e-03      0.330017  0.000000e+00  0.000000e+00
# 55996      0.938947  3.398603e-06      0.104751  3.541345e-08  0.000000e+00
# 55997      0.938201  1.272371e-04      0.030063  0.000000e+00  0.000000e+00
# 55998      0.991289  1.542866e-06      0.088936  5.378431e-08  5.711690e-08
# 55999      0.758456  4.411263e-05      0.187442  0.000000e+00  0.000000e+00
#
# ...

# %%
new_train1_scaled["default_status"]= TRAIN["default_status"] #adds target feature to scaled dataframe
new_train1_scaled
# Out:
#        form_field14  form_field28  form_field10   form_field3   form_field4  \
# 0          0.982779  6.118462e-07      0.115569  1.688695e-08  0.000000e+00
# 1          0.936902  1.012095e-05      0.084336  7.797130e-09  0.000000e+00
# 2          0.992062  3.590860e-06      0.064627  1.885800e-07  0.000000e+00
# 3          0.991398  1.234428e-06      0.074518  1.038977e-08  0.000000e+00
# 4          0.998234  2.128323e-06      0.012833  3.905474e-08  0.000000e+00
# ...             ...           ...           ...           ...           ...
# 55995      0.798688  1.007274e-03      0.330017  0.000000e+00  0.000000e+00
# 55996      0.938947  3.398603e-06      0.104751  3.541345e-08  0.000000e+00
# 55997      0.938201  1.272371e-04      0.030063  0.000000e+00  0.000000e+00
# 55998      0.991289  1.542866e-06      0.088936  5.378431e-08  5.711690e-08
# 55999      0.758456  4.411263e-05      0.187442  0.000000e+00  0.000000e+00
#
# ...

# %% [markdown]
# PREPROCESSING TEST DATA

# %%
TEST = pd.read_csv("C://Users//Abdulrazaq//Documents//py learn//Zindi//zindi_dataset//dsn_hackathon_qualif//Test.csv")

# %%
TEST
# Out:
#         Applicant_ID  form_field1  form_field2  form_field3  form_field4  \
# 0      Apcnt_1000032       3236.0      0.34875      10.2006       0.0000
# 1      Apcnt_1000048       3284.0      1.27360       2.9606       9.0198
# 2      Apcnt_1000052          NaN      0.27505       0.0600       0.0000
# 3      Apcnt_1000076       3232.0      0.28505       2.8032       0.0000
# 4      Apcnt_1000080       3466.0      2.09545       0.8318       2.5182
# ...              ...          ...          ...          ...          ...
# 23995   Apcnt_999940       3258.0      0.37925       0.5698       5.1282
# 23996   Apcnt_999956       3514.0      0.95260       0.0000       0.0000
# 23997   Apcnt_999976       3302.0      0.05755       4.2394       0.0000
# 23998   Apcnt_999984       3334.0      0.75670       1.4428       0.0000
# 23999   Apcnt_999992       3324.0      0.44840       2.3170       6.7176
#
#        form_field5  form_field6  form_field7  form_field8  form_field9  ...  \
# ...

# %%
from sklearn.model_selection import train_test_split #for splitting dataset into train and test
y_normalized = pd.DataFrame()
X_normalized = new_train1_scaled.drop(columns=["default_status"])
y_normalized["default_status"] = new_train1_scaled["default_status"] #creates new dataframe with target feature

# %%
new_train1_scaled.shape, TEST.shape,new_train1_scaled.columns, TEST.columns, X_normalized.columns
# Out:
# ((56000, 38),
#  (24000, 51),
#  Index(['form_field14', 'form_field28', 'form_field10', 'form_field3',
#         'form_field4', 'form_field34', 'form_field5', 'form_field29',
#         'form_field20', 'form_field49', 'form_field38', 'form_field43',
#         'form_field42', 'form_field36', 'form_field1', 'form_field2',
#         'form_field39', 'form_field7', 'form_field44', 'form_field27',
#         'form_field9', 'form_field26', 'form_field13', 'form_field32',
#         'form_field25', 'form_field37', 'form_field22', 'form_field46',
#         'form_field21', 'form_field8', 'form_field6', 'form_field24',
#         'form_field16', 'form_field50', 'form_field18', 'form_field12',
#         'form_field47', 'default_status'],
#        dtype='object'),
#  Index(['Applicant_ID', 'form_field1', 'form_field2', 'form_field3',
#         'form_field4', 'form_field5', 'form_field6', 'form_field7',
#         'form_field8', 'form_field9', 'form_field10', 'form_field11',
# ...

# %%
TEST_COL =['Applicant_ID', 'form_field1', 'form_field2', 'form_field3',
        'form_field4', 'form_field5', 'form_field6', 'form_field7',
        'form_field8', 'form_field9', 'form_field10', 'form_field11',
        'form_field12', 'form_field13', 'form_field14', 'form_field15',
        'form_field16', 'form_field17', 'form_field18', 'form_field19',
        'form_field20', 'form_field21', 'form_field22', 'form_field23',
        'form_field24', 'form_field25', 'form_field26', 'form_field27',
        'form_field28', 'form_field29', 'form_field30', 'form_field31',
        'form_field32', 'form_field33', 'form_field34', 'form_field35',
        'form_field36', 'form_field37', 'form_field38', 'form_field39',
        'form_field40', 'form_field41', 'form_field42', 'form_field43',
        'form_field44', 'form_field45', 'form_field46', 'form_field47',
        'form_field48', 'form_field49', 'form_field50']
scaled_Col =['form_field14', 'form_field28', 'form_field10', 'form_field3',
        'form_field4', 'form_field34', 'form_field5', 'form_field29',
        'form_field20', 'form_field49', 'form_field38', 'form_field43',
        'form_field42', 'form_field36', 'form_field1', 'form_field2',
        'form_field39', 'form_field7', 'form_field44', 'form_field27',
        'form_field9', 'form_field26', 'form_field13', 'form_field32',
        'form_field25', 'form_field37', 'form_field22', 'form_field46',
        'form_field21', 'form_field8', 'form_field6', 'form_field24',
        'form_field16', 'form_field50', 'form_field18', 'form_field12',
        'form_field47']
new_test = TEST[scaled_Col]
new_test.shape, X_normalized.shape,new_test.columns, X_normalized.columns
# Out:
# ((24000, 37),
#  (56000, 37),
#  Index(['form_field14', 'form_field28', 'form_field10', 'form_field3',
#         'form_field4', 'form_field34', 'form_field5', 'form_field29',
#         'form_field20', 'form_field49', 'form_field38', 'form_field43',
#         'form_field42', 'form_field36', 'form_field1', 'form_field2',
#         'form_field39', 'form_field7', 'form_field44', 'form_field27',
#         'form_field9', 'form_field26', 'form_field13', 'form_field32',
#         'form_field25', 'form_field37', 'form_field22', 'form_field46',
#         'form_field21', 'form_field8', 'form_field6', 'form_field24',
#         'form_field16', 'form_field50', 'form_field18', 'form_field12',
#         'form_field47'],
#        dtype='object'),
#  Index(['form_field14', 'form_field28', 'form_field10', 'form_field3',
#         'form_field4', 'form_field34', 'form_field5', 'form_field29',
#         'form_field20', 'form_field49', 'form_field38', 'form_field43',
# ...

# %%
#fill null values in new_test dataframe
new_test.median()
# Out:
# form_field14    2.814143e+07
# form_field28    4.860000e+02
# form_field10    3.651543e+06
# form_field3     5.820000e-02
# form_field4     0.000000e+00
# form_field34    0.000000e+00
# form_field5     0.000000e+00
# form_field29    1.505700e+04
# form_field20    0.000000e+00
# form_field49    0.000000e+00
# form_field38    6.000000e+00
# form_field43    5.050000e+00
# form_field42    2.200000e-01
# form_field36    1.000000e+01
# form_field1     3.484000e+03
# form_field2     2.732500e-01
# form_field39    0.000000e+00
# form_field7     2.719888e+06
# form_field44    5.921000e-01
# form_field27    5.110000e+03
# form_field9     5.529830e+06
# form_field26    8.214000e+03
# form_field13    1.563391e+06
# form_field32    6.000000e+02
# form_field25    2.212500e+03
# form_field37    6.000000e+00
# form_field22    5.918475e+03
# form_field46    0.000000e+00
# form_field21    9.013500e+01
# form_field8     9.594685e+05
# form_field6     1.155330e+05
# form_field24    6.069000e+01
# ...

# %%
new_test[new_test.isna().any(axis = 1)]
# Out:
#        form_field14  form_field28  form_field10  form_field3  form_field4  \
# 0          48187375          60.0           0.0      10.2006       0.0000
# 1          34694910          60.0    18308285.0       2.9606       9.0198
# 2          21973443         852.0           0.0       0.0600       0.0000
# 3          16576457          60.0      493641.0       2.8032       0.0000
# 5          34694910           NaN           NaN          NaN          NaN
# ...             ...           ...           ...          ...          ...
# 23992      33538413          60.0           0.0       4.1564      11.4642
# 23993      50114870          60.0     9310715.0       2.9862       6.3324
# 23995      21973443         304.0     2280318.0       0.5698       5.1282
# 23997      21973443          60.0       49403.0       4.2394       0.0000
# 23999      48187375          60.0     5361587.0       2.3170       6.7176
#
#        form_field34  form_field5  form_field29  form_field20  form_field49  \
# ...

# %%
new_test=new_test.fillna(new_test.median())

# %%
new_test.isnull().sum()
# Out:
# form_field14    0
# form_field28    0
# form_field10    0
# form_field3     0
# form_field4     0
# form_field34    0
# form_field5     0
# form_field29    0
# form_field20    0
# form_field49    0
# form_field38    0
# form_field43    0
# form_field42    0
# form_field36    0
# form_field1     0
# form_field2     0
# form_field39    0
# form_field7     0
# form_field44    0
# form_field27    0
# form_field9     0
# form_field26    0
# form_field13    0
# form_field32    0
# form_field25    0
# form_field37    0
# form_field22    0
# form_field46    0
# form_field21    0
# form_field8     0
# form_field6     0
# form_field24    0
# form_field16    0
# form_field50    0
# form_field18    0
# form_field12    0
# form_field47    0
# dtype: int64

# %%
new_test["form_field32"]
# Out:
# 0         238.0
# 1        1216.0
# 2         600.0
# 3         248.0
# 4        2388.0
#           ...
# 23995      24.0
# 23996     586.0
# 23997     202.0
# 23998      62.0
# 23999    1634.0
# Name: form_field32, Length: 24000, dtype: float64

# %%
new_test["form_field32"]= new_test["form_field32"]*30

# %%
new_test["form_field32"]
# Out:
# 0         7140.0
# 1        36480.0
# 2        18000.0
# 3         7440.0
# 4        71640.0
#           ...
# 23995      720.0
# 23996    17580.0
# 23997     6060.0
# 23998     1860.0
# 23999    49020.0
# Name: form_field32, Length: 24000, dtype: float64

# %%
#normalize test set
new_test_col = new_test.drop(columns = ["form_field47"])
new_test = pd.DataFrame(scaler.fit_transform(new_test.drop(columns=["form_field47"])),
                                                      columns = new_test_col.columns)
new_test
# Out:
#        form_field14  form_field28  form_field10   form_field3   form_field4  \
# 0          0.999824      0.000001      0.000000  2.116489e-07  0.000000e+00
# 1          0.856361      0.000001      0.451896  7.307533e-08  2.226322e-07
# 2          0.958535      0.000037      0.000000  2.617346e-09  0.000000e+00
# 3          0.988307      0.000004      0.029431  1.671299e-07  0.000000e+00
# 4          0.974969      0.000004      0.116398  1.682971e-08  5.095043e-08
# ...             ...           ...           ...           ...           ...
# 23995      0.958027      0.000013      0.099420  2.484289e-08  2.235860e-07
# 23996      0.561126      0.000354      0.075690  0.000000e+00  0.000000e+00
# 23997      0.967635      0.000003      0.002176  1.866886e-07  0.000000e+00
# 23998      0.976199      0.000000      0.150234  8.496753e-08  0.000000e+00
# 23999      0.919613      0.000001      0.102321  4.421786e-08  1.281994e-07
#
# ...

# %%
new_test["form_field47"] = TEST["form_field47"] #encoding form_field47 for test data
new_test["form_field47"] = encoder.fit_transform(new_test.form_field47.values)
new_test
# Out:
#        form_field14  form_field28  form_field10   form_field3   form_field4  \
# 0          0.999824      0.000001      0.000000  2.116489e-07  0.000000e+00
# 1          0.856361      0.000001      0.451896  7.307533e-08  2.226322e-07
# 2          0.958535      0.000037      0.000000  2.617346e-09  0.000000e+00
# 3          0.988307      0.000004      0.029431  1.671299e-07  0.000000e+00
# 4          0.974969      0.000004      0.116398  1.682971e-08  5.095043e-08
# ...             ...           ...           ...           ...           ...
# 23995      0.958027      0.000013      0.099420  2.484289e-08  2.235860e-07
# 23996      0.561126      0.000354      0.075690  0.000000e+00  0.000000e+00
# 23997      0.967635      0.000003      0.002176  1.866886e-07  0.000000e+00
# 23998      0.976199      0.000000      0.150234  8.496753e-08  0.000000e+00
# 23999      0.919613      0.000001      0.102321  4.421786e-08  1.281994e-07
#
# ...

# %%
X_normalized.shape, new_test.shape #equal number of columns
# Out:
# ((56000, 37), (24000, 37))

# %%
X_normalized
# Out:
#        form_field14  form_field28  form_field10   form_field3   form_field4  \
# 0          0.982779  6.118462e-07      0.115569  1.688695e-08  0.000000e+00
# 1          0.936902  1.012095e-05      0.084336  7.797130e-09  0.000000e+00
# 2          0.992062  3.590860e-06      0.064627  1.885800e-07  0.000000e+00
# 3          0.991398  1.234428e-06      0.074518  1.038977e-08  0.000000e+00
# 4          0.998234  2.128323e-06      0.012833  3.905474e-08  0.000000e+00
# ...             ...           ...           ...           ...           ...
# 55995      0.798688  1.007274e-03      0.330017  0.000000e+00  0.000000e+00
# 55996      0.938947  3.398603e-06      0.104751  3.541345e-08  0.000000e+00
# 55997      0.938201  1.272371e-04      0.030063  0.000000e+00  0.000000e+00
# 55998      0.991289  1.542866e-06      0.088936  5.378431e-08  5.711690e-08
# 55999      0.758456  4.411263e-05      0.187442  0.000000e+00  0.000000e+00
#
# ...

# %%
y_normalized
# Out:
#        default_status
# 0                   0
# 1                   0
# 2                   1
# 3                   0
# 4                   0
# ...               ...
# 55995               0
# 55996               1
# 55997               0
# 55998               0
# 55999               0
#
# [56000 rows x 1 columns]

# %%
X_train_norm,X_test_norm,y_train_norm,y_test_norm = train_test_split(X_normalized,y_normalized,
                                                                    test_size = 0.3,shuffle = True)
X_train_norm.shape,X_test_norm.shape,y_train_norm.shape,y_test_norm.shape
# Out:
# ((39200, 37), (16800, 37), (39200, 1), (16800, 1))

# %%
X_train_norm.head()
# Out:
#        form_field14  form_field28  form_field10   form_field3  form_field4  \
# 16119      0.859500      0.000172      0.076865  0.000000e+00          0.0
# 14536      0.687618      0.001204      0.445691  0.000000e+00          0.0
# 38924      0.900831      0.000000      0.306105  4.458926e-07          0.0
# 40805      0.736433      0.003870      0.232275  0.000000e+00          0.0
# 15248      0.813195      0.000005      0.190375  0.000000e+00          0.0
#
#        form_field34  form_field5  form_field29  form_field20  form_field49  \
# 16119           0.0     0.000000      0.001187  0.000000e+00  0.000000e+00
# 14536           0.0     0.000000      0.000553  0.000000e+00  0.000000e+00
# 38924           0.0     0.000004      0.000729  1.086880e-07  4.286949e-07
# 40805           0.0     0.000000      0.000825  2.547116e-07  2.547116e-07
# 15248           0.0     0.000000      0.001227  0.000000e+00  0.000000e+00
#
# ...

# %% [markdown]
# USING DECISION TREE CLASSIFIER

# %%
from sklearn.tree import DecisionTreeClassifier
dec_tree = DecisionTreeClassifier(class_weight = "balanced",min_samples_leaf = 4,
                                  max_leaf_nodes = 320,
                                 max_depth = 120,max_features =14,
                                 min_weight_fraction_leaf=0.01)
                                  #dec_tree?

dec_tree.fit(X_train_norm,y_train_norm)
dec_tree_pred = dec_tree.predict(X_train_norm)

#auc(y_train_norm,dec_tree_pred) cross_val_score(sgd_clf, X_train, y_train, cv=3, scoring="accuracy")

# %%
from sklearn.metrics import auc,roc_auc_score,accuracy_score,classification_report,confusion_matrix,precision_score,recall_score
roc_auc_score(dec_tree_pred,y_train_norm)
#print(classification_report(dec_tree_pred,y_train_norm))
#confusion_matrix(dec_tree_pred,y_train_norm)
# Out:
# 0.6626220129097038

# %%
from sklearn.metrics import *
dec_tree_predict = dec_tree.predict(X_test_norm)
roc_auc_score(dec_tree_predict,y_test_norm)
#fpr, tpr, thresholds =roc_curve(dec_tree_predict,y_test_norm, pos_label=2)
#auc(fpr, tpr)
#auc(dec_tree_predict,y_test_norm)
# Out:
# 0.6556214195802399

# %% [markdown]
# Decision Tree prediction on test data

# %%
dec_tree_new_test = pd.DataFrame()
dec_tree_new_test["Aopplicant_ID"]= TEST["Applicant_ID"]
dec_tree_new_test["default_status"] =dec_tree.predict(new_test)

dec_tree_new_test
# Out:
#        Aopplicant_ID  default_status
# 0      Apcnt_1000032               0
# 1      Apcnt_1000048               0
# 2      Apcnt_1000052               0
# 3      Apcnt_1000076               1
# 4      Apcnt_1000080               0
# ...              ...             ...
# 23995   Apcnt_999940               1
# 23996   Apcnt_999956               0
# 23997   Apcnt_999976               1
# 23998   Apcnt_999984               1
# 23999   Apcnt_999992               0
#
# [24000 rows x 2 columns]

# %%
dec_tree_new_test.to_csv("Submission2.csv", index= False)

# %%
from sklearn.metrics import roc_curve
import matplotlib.pyplot as plt
fpr, tpr, thresholds = roc_curve(dec_tree_predict,y_test_norm)
#Then you can plot the FPR against the TPR using Matplotlib. This code produces the
#plot in Figure 3-6:
def plot_roc_curve(fpr, tpr, label=None):
    
    plt.plot(fpr, tpr, linewidth=2, label=label)
    plt.plot([0, 1], [0, 1], 'k--') # dashed diagonal
 #[...] # Add axis labels and grid
plot_roc_curve(fpr, tpr)
plt.show()

# %%
#ensenble random forest based on decion tree
from sklearn.ensemble import RandomForestClassifier
from sklearn.model_selection import cross_val_score,cross_val_predict
from sklearn.model_selection import GridSearchCV
rdf_clf = RandomForestClassifier(n_estimators = 700,min_samples_leaf = 4,max_leaf_nodes = 50,
                         max_depth = 30,max_features = 4,
                         min_samples_split=3,
                             criterion = "entropy",
                        random_state = 202
                                )
rdf_clf.fit(X_train_norm,y_train_norm,)

#prediction on train data

rdf_clf_pred =rdf_clf.predict(X_train_norm)
#metrics on train data for RANDOM FOREST
roc_auc_score(rdf_clf_pred,y_train_norm),accuracy_score(rdf_clf_pred,y_train_norm),log_loss(rdf_clf_pred,y_train_norm)
# Out:
# C:\Users\Abdulrazaq\Anaconda3\lib\site-packages\ipykernel_launcher.py:10: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   # Remove the CWD from sys.path while we load stuff.
# (0.7570391492811059, 0.7731122448979592, 7.836598801910583)

# %%
#new random_forest based on grid search best parameters
random_frst = RandomForestClassifier(class_weight = "balanced",
                                     max_depth= 30,
                                      max_leaf_nodes= 50,
                                    min_samples_split= 3,
                                    n_estimators= 600)
random_frst.fit(X_train_norm,y_train_norm)
frts_pred = random_frst.predict(X_train_norm)

#fitting directly with grid search

grid_pred =  grid_search.predict(X_train_norm)
roc_auc_score(grid_pred,y_train_norm),accuracy_score(grid_pred,y_train_norm),log_loss(grid_pred,y_train_norm)
# Out:
# C:\Users\Abdulrazaq\Anaconda3\lib\site-packages\ipykernel_launcher.py:6: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
# (0.7535297490397878, 0.7729591836734694, 7.841885063747456)

# %%
grid_predict =  grid_search.predict(X_test_norm)
roc_auc_score(grid_predict,y_test_norm),accuracy_score(grid_predict,y_test_norm),log_loss(grid_predict,y_test_norm)
# Out:
# (0.7361043800916128, 0.7719642857142858, 7.876247268331965)

# %%
grid_new_test["default_status"].value_counts()
# Out:
# 0    23118
# 1      882
# Name: default_status, dtype: int64

# %%
roc_auc_score(frts_pred,y_train_norm),accuracy_score(frts_pred,y_train_norm),log_loss(frts_pred,y_train_norm)
# Out:
# (0.6775196553860081, 0.7063520408163265, 10.142281609294033)

# %%
#test data in train test split
frst_predict = random_frst.predict(X_test_norm)
roc_auc_score(frst_predict,y_test_norm),accuracy_score(frst_predict,y_test_norm),log_loss(frst_predict,y_test_norm)
# Out:
# (0.6690591793135977, 0.6993452380952381, 10.384291142996577)

# %%
"new random forest with grid search suggestions did better than fitting grid search directly"

# %%
rdf_new_test = pd.DataFrame()
rdf_new_test["Aopplicant_ID"]= TEST["Applicant_ID"]
rdf_new_test["default_status"] =rdf_clf.predict(new_test)
# Out:
#        Aopplicant_ID  default_status
# 0      Apcnt_1000032               0
# 1      Apcnt_1000048               0
# 2      Apcnt_1000052               0
# 3      Apcnt_1000076               0
# 4      Apcnt_1000080               0
# ...              ...             ...
# 23995   Apcnt_999940               0
# 23996   Apcnt_999956               0
# 23997   Apcnt_999976               0
# 23998   Apcnt_999984               0
# 23999   Apcnt_999992               0
#
# [24000 rows x 2 columns]

# %%
rdf_new_test.to_csv("Submission3_rdf1.csv", index= False)

# %%
fpr, tpr, thresholds = roc_curve(rdf_clf_predict,y_test_norm)
#Then you can plot the FPR against the TPR using Matplotlib. This code produces the
#plot in Figure 3-6:
def plot_roc_curve(fpr, tpr, label=None):
    
    plt.plot(fpr, tpr, linewidth=2, label=label)
    plt.plot([0, 1], [0, 1], 'k--') # dashed diagonal
 #[...] # Add axis labels and grid
plot_roc_curve(fpr, tpr)
plt.show()
#dec_tree?  #better score as compared to Decision Tree

# %%
parameters2 = [{"n_estimators":[300,600], "max_leaf_nodes": [50,60],
              "min_samples_split":[3],
               "max_depth": [30,40],"class_weight":["balanced"]},
              
             {"n_estimators":[700], "max_leaf_nodes": [55],
              "min_samples_split":[2],
               "max_depth" : [45],"class_weight":["balanced"]}]
grid_search2 = GridSearchCV(random_frst,
                          param_grid= parameters2,
                          scoring = "roc_auc",
                           cv =5,
                           n_jobs = -1)
# Out:
# C:\Users\Abdulrazaq\Anaconda3\lib\site-packages\sklearn\model_selection\_search.py:765: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   self.best_estimator_.fit(X, y, **fit_params)
# GridSearchCV(cv=5,
#              estimator=RandomForestClassifier(criterion='entropy', max_depth=30,
#                                               max_features=4, max_leaf_nodes=50,
#                                               min_samples_leaf=4,
#                                               n_estimators=700,
#                                               random_state=202),
#              n_jobs=-1,
#              param_grid=[{'max_depth': [30, 43, 32],
#                           'max_leaf_nodes': [10, 20, 50, 34, 40],
#                           'min_samples_split': [3, 4, 1, 2, 5],
#                           'n_estimators': [100, 300, 600, 200]},
# ...

# %%
grid_search2.fit(X_train_norm,y_train_norm)
# Out:
# C:\Users\Abdulrazaq\Anaconda3\lib\site-packages\sklearn\model_selection\_search.py:765: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   self.best_estimator_.fit(X, y, **fit_params)
# GridSearchCV(cv=5,
#              estimator=RandomForestClassifier(class_weight='balanced',
#                                               max_depth=30, max_leaf_nodes=50,
#                                               min_samples_split=3,
#                                               n_estimators=600),
#              n_jobs=-1,
#              param_grid=[{'class_weight': ['balanced'], 'max_depth': [30, 40],
#                           'max_leaf_nodes': [50, 60], 'min_samples_split': [3],
#                           'n_estimators': [300, 600]},
#                          {'class_weight': ['balanced'], 'max_depth': [45],
# ...

# %%
grid_search2.best_score_
# Out:
# 0.8011943708093598

# %%
grid_search2.best_params_,grid_search2.best_estimator_
# Out:
# ({'class_weight': 'balanced',
#   'max_depth': 30,
#   'max_leaf_nodes': 60,
#   'min_samples_split': 3,
#   'n_estimators': 600},
#  RandomForestClassifier(class_weight='balanced', max_depth=30, max_leaf_nodes=60,
#                         min_samples_split=3, n_estimators=600))

# %%
grid2_pred =  grid_search2.predict(X_train_norm)
roc_auc_score(grid2_pred,y_train_norm),accuracy_score(grid2_pred,y_train_norm),log_loss(grid2_pred,y_train_norm)
# Out:
# (0.6799646811184373, 0.7099744897959184, 10.017166368415426)

# %%
grid2_predict =  grid_search2.predict(X_test_norm)
roc_auc_score(grid2_predict,y_test_norm),accuracy_score(grid2_predict,y_test_norm),log_loss(grid2_predict,y_test_norm)
# Out:
# (0.6713560528280468, 0.7025595238095238, 10.273273266680825)

# %%
rf_grid2 = RandomForestClassifier(class_weight='balanced', max_depth=30, max_leaf_nodes=60,
                        min_samples_split=3, n_estimators=600) #using gridsearch2 parameters
rf_grid2.fit(X_train_norm,y_train_norm)
# Out:
# C:\Users\Abdulrazaq\Anaconda3\lib\site-packages\ipykernel_launcher.py:3: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   This is separate from the ipykernel package so we can avoid doing imports until
# RandomForestClassifier(class_weight='balanced', max_depth=30, max_leaf_nodes=60,
#                        min_samples_split=3, n_estimators=600)

# %%
rf_grid2_pred = rf_grid2.predict(X_train_norm)
roc_auc_score(rf_grid2_pred,y_train_norm),accuracy_score(rf_grid2_pred,y_train_norm),log_loss(rf_grid2_pred,y_train_norm)
# Out:
# (0.6799984788053264, 0.7103571428571429, 10.003950183478008)

# %%
rf_grid2_predict = rf_grid2.predict(X_test_norm)
roc_auc_score(rf_grid2_predict,y_test_norm),accuracy_score(rf_grid2_predict,y_test_norm),log_loss(rf_grid2_predict,y_test_norm)
# Out:
# (0.6710405129306243, 0.7020238095238095, 10.291776182606668)

# %%
rf_grid2_new_test = pd.DataFrame()
rf_grid2_new_test["Applicant_ID"]= TEST["Applicant_ID"]
#rf_grid2_new_test1 =rf_grid2.predict_proba(new_test)[:,1]

rf_grid2_new_test["default_status"]= rf_grid2.predict_proba(new_test)[:,1]
rf_grid2_new_test
# Out:
#         Applicant_ID  default_status
# 0      Apcnt_1000032        0.615267
# 1      Apcnt_1000048        0.417410
# 2      Apcnt_1000052        0.628126
# 3      Apcnt_1000076        0.744741
# 4      Apcnt_1000080        0.293984
# ...              ...             ...
# 23995   Apcnt_999940        0.634335
# 23996   Apcnt_999956        0.285759
# 23997   Apcnt_999976        0.760307
# 23998   Apcnt_999984        0.734917
# 23999   Apcnt_999992        0.410963
#
# [24000 rows x 2 columns]

# %%
rf_grid2_new_test.to_csv("rfgrid2_prob.csv", index = False)

# %% [markdown]
# USING CATBOOST CLASSIFIER

# %%
import catboost
from catboost import CatBoostClassifier
catfeat = ["form_field47"]
catbst_clf = CatBoostClassifier(iterations = 1000, random_state = 42,
                               eval_metric = "AUC")
catbst_clf.fit(X_train_norm,y_train_norm,
               cat_features = catfeat,
               
               eval_set = (X_test_norm,y_test_norm))
catbst_clf_pred =catbst_clf.predict(X_train_norm)
roc_auc_score(catbst_clf_pred,y_train_norm),accuracy_score(catbst_clf_pred,y_train_norm),log_loss(catbst_clf_pred,y_train_norm)
# Out:
# Learning rate set to 0.078424
# 0:	test: 0.7851193	best: 0.7851193 (0)	total: 183ms	remaining: 3m 2s
# 1:	test: 0.7930149	best: 0.7930149 (1)	total: 352ms	remaining: 2m 55s
# 2:	test: 0.8004444	best: 0.8004444 (2)	total: 521ms	remaining: 2m 53s
# 3:	test: 0.8016171	best: 0.8016171 (3)	total: 735ms	remaining: 3m 3s
# 4:	test: 0.8061286	best: 0.8061286 (4)	total: 911ms	remaining: 3m 1s
# 5:	test: 0.8065898	best: 0.8065898 (5)	total: 1.1s	remaining: 3m 2s
# 6:	test: 0.8082432	best: 0.8082432 (6)	total: 1.25s	remaining: 2m 56s
# 7:	test: 0.8095019	best: 0.8095019 (7)	total: 1.4s	remaining: 2m 53s
# 8:	test: 0.8110598	best: 0.8110598 (8)	total: 1.49s	remaining: 2m 44s
# 9:	test: 0.8126104	best: 0.8126104 (9)	total: 1.6s	remaining: 2m 38s
# 10:	test: 0.8147964	best: 0.8147964 (10)	total: 1.72s	remaining: 2m 34s
# 11:	test: 0.8154014	best: 0.8154014 (11)	total: 1.86s	remaining: 2m 33s
# 12:	test: 0.8173939	best: 0.8173939 (12)	total: 1.95s	remaining: 2m 28s
# ...

# %%
catboost_clf_predict = catbst_clf.predict(X_test_norm)
roc_auc_score(rdf_clf_predict,y_test_norm),accuracy_score(rdf_clf_predict,y_test_norm),log_loss(rdf_clf_predict,y_test_norm)
# Out:
# (0.738602671671966, 0.7716666666666666, 7.886527522780078)

# %%
#grid search for catboost
 
parameters_cat = [{"iterations":[100,300,299,750,600], "learning_rate": [0.1,0.5,0.04,0.07],
              "loss_function": ["CrossEntropy"],"depth":[4,6,1,5,7,9],"l2_leaf_reg":[3,6,9,50],
              "border_count":[12,50,30]}
             ]
grid_searchCat = GridSearchCV(catbst_clf,
                          param_grid= parameters_cat,
                          scoring = "roc_auc",
                           cv =5,
                           n_jobs = -1)

# %%
grid_searchCat.fit(X_train_norm,y_train_norm)
# Out:
# 0:	total: 302ms	remaining: 3m
# 1:	total: 524ms	remaining: 2m 36s
# 2:	total: 591ms	remaining: 1m 57s
# 3:	total: 895ms	remaining: 2m 13s
# 4:	total: 1.11s	remaining: 2m 12s
# 5:	total: 1.25s	remaining: 2m 3s
# 6:	total: 1.32s	remaining: 1m 52s
# 7:	total: 1.5s	remaining: 1m 51s
# 8:	total: 1.66s	remaining: 1m 49s
# 9:	total: 1.76s	remaining: 1m 43s
# 10:	total: 1.83s	remaining: 1m 38s
# 11:	total: 1.92s	remaining: 1m 34s
# 12:	total: 2.07s	remaining: 1m 33s
# 13:	total: 2.15s	remaining: 1m 30s
# 14:	total: 2.23s	remaining: 1m 26s
# 15:	total: 2.32s	remaining: 1m 24s
# 16:	total: 2.39s	remaining: 1m 22s
# 17:	total: 2.45s	remaining: 1m 19s
# 18:	total: 2.53s	remaining: 1m 17s
# 19:	total: 2.62s	remaining: 1m 15s
# 20:	total: 2.72s	remaining: 1m 14s
# 21:	total: 2.8s	remaining: 1m 13s
# 22:	total: 2.88s	remaining: 1m 12s
# 23:	total: 2.95s	remaining: 1m 10s
# 24:	total: 3.05s	remaining: 1m 10s
# 25:	total: 3.18s	remaining: 1m 10s
# 26:	total: 3.26s	remaining: 1m 9s
# ...

# %%
grid_searchCat.best_score_,grid_searchCat.best_params_
# Out:
# (0.8306649946407095,
#  {'border_count': 50,
#   'depth': 6,
#   'iterations': 600,
#   'l2_leaf_reg': 50,
#   'learning_rate': 0.04,
#   'loss_function': 'CrossEntropy'})

# %%
new_catboost = CatBoostClassifier(border_count= 50,
                                  depth= 6,
                                  
                                  iterations= 600,
                                  l2_leaf_reg= 50,
                                  learning_rate= 0.04,
                                  loss_function= 'CrossEntropy') #catboost model based on best parameters

# %%
new_catboost.fit(X_train_norm,y_train_norm)
# Out:
# 0:	learn: 0.6697203	total: 96ms	remaining: 57.5s
# 1:	learn: 0.6472548	total: 186ms	remaining: 55.6s
# 2:	learn: 0.6277939	total: 274ms	remaining: 54.6s
# 3:	learn: 0.6106818	total: 361ms	remaining: 53.8s
# 4:	learn: 0.5942094	total: 422ms	remaining: 50.2s
# 5:	learn: 0.5794598	total: 483ms	remaining: 47.8s
# 6:	learn: 0.5684124	total: 544ms	remaining: 46.1s
# 7:	learn: 0.5571865	total: 619ms	remaining: 45.8s
# 8:	learn: 0.5488668	total: 676ms	remaining: 44.4s
# 9:	learn: 0.5398302	total: 741ms	remaining: 43.7s
# 10:	learn: 0.5314018	total: 837ms	remaining: 44.8s
# 11:	learn: 0.5240140	total: 961ms	remaining: 47.1s
# 12:	learn: 0.5158690	total: 1.09s	remaining: 49.1s
# 13:	learn: 0.5094787	total: 1.21s	remaining: 50.7s
# 14:	learn: 0.5038293	total: 1.34s	remaining: 52.2s
# 15:	learn: 0.4985901	total: 1.47s	remaining: 53.8s
# 16:	learn: 0.4938109	total: 1.57s	remaining: 53.9s
# 17:	learn: 0.4898735	total: 1.68s	remaining: 54.4s
# 18:	learn: 0.4852894	total: 1.77s	remaining: 54.3s
# ...

# %%
new_cat_pred =new_catboost.predict(X_train_norm)
roc_auc_score(new_cat_pred,y_train_norm),accuracy_score(new_cat_pred,y_train_norm),log_loss(new_cat_pred,y_train_norm)
# Out:
# (0.7942908959171525, 0.8313010204081632, 5.826757956478102)

# %%
new_cat_predict = new_catboost.predict(X_test_norm)
roc_auc_score(new_cat_predict,y_test_norm),accuracy_score(new_cat_predict,y_test_norm),log_loss(new_cat_predict,y_test_norm)
# Out:
# (0.7549821964140178, 0.81125, 6.519303227664682)

# %%
grid_cat_pred =grid_searchCat.predict(X_train_norm)
roc_auc_score(grid_cat_pred,y_train_norm),accuracy_score(grid_cat_pred,y_train_norm),log_loss(grid_cat_pred,y_train_norm)
# Out:
# (0.7947592109256448, 0.8314030612244898, 5.823233754722995)

# %%
grid_cat_predict = grid_searchCat.predict(X_test_norm)
roc_auc_score(grid_cat_predict,y_test_norm),accuracy_score(grid_cat_predict,y_test_norm),log_loss(grid_cat_predict,y_test_norm)

# %%
cat_random_params1=[{"iterations":[300], "learning_rate": [0.09,0.08],
              "loss_function": ["CrossEntropy"],
                     "depth":[4,3],"l2_leaf_reg":[80,90],
              "border_count":[80,90],
                    
                    'leaf_estimation_iterations':[4,16]}
             ]

randomized_cat1 = RandomizedSearchCV(new_catboost,
                          param_distributions= cat_random_params1,
                          scoring = "roc_auc",
                           cv =5,
                           n_jobs = -1) #random search on new catboost

# %%
randomized_cat1.fit(X_train_norm,y_train_norm)
# Out:
# 0:	learn: 0.6471442	total: 35.8ms	remaining: 10.7s
# 1:	learn: 0.6105606	total: 73.7ms	remaining: 11s
# 2:	learn: 0.5812679	total: 110ms	remaining: 10.9s
# 3:	learn: 0.5564954	total: 144ms	remaining: 10.6s
# 4:	learn: 0.5373155	total: 177ms	remaining: 10.5s
# 5:	learn: 0.5202892	total: 215ms	remaining: 10.5s
# 6:	learn: 0.5070726	total: 266ms	remaining: 11.1s
# 7:	learn: 0.4965203	total: 315ms	remaining: 11.5s
# 8:	learn: 0.4879897	total: 352ms	remaining: 11.4s
# 9:	learn: 0.4805330	total: 389ms	remaining: 11.3s
# 10:	learn: 0.4747646	total: 443ms	remaining: 11.6s
# 11:	learn: 0.4698760	total: 491ms	remaining: 11.8s
# 12:	learn: 0.4658746	total: 526ms	remaining: 11.6s
# 13:	learn: 0.4629015	total: 567ms	remaining: 11.6s
# 14:	learn: 0.4597798	total: 608ms	remaining: 11.6s
# 15:	learn: 0.4570645	total: 648ms	remaining: 11.5s
# 16:	learn: 0.4534288	total: 691ms	remaining: 11.5s
# 17:	learn: 0.4506220	total: 728ms	remaining: 11.4s
# 18:	learn: 0.4478955	total: 763ms	remaining: 11.3s
# ...

# %%
randomized_cat1.best_score_,randomized_cat1.best_params_
# Out:
# (0.8296917020282333,
#  {'loss_function': 'CrossEntropy',
#   'learning_rate': 0.09,
#   'leaf_estimation_iterations': 4,
#   'l2_leaf_reg': 80,
#   'iterations': 300,
#   'depth': 4,
#   'border_count': 90})

# %%
random_cat_pred1 =randomized_cat1.predict(X_train_norm)
roc_auc_score(random_cat_pred1,y_train_norm),accuracy_score(random_cat_pred1,y_train_norm),log_loss(random_cat_pred1,y_train_norm)
# Out:
# (0.7640308009901623, 0.814795918367347, 6.396831042912236)

# %%
random_cat_predict1 = randomized_cat1.predict(X_test_norm)
roc_auc_score(random_cat_predict1,y_test_norm),accuracy_score(random_cat_predict1,y_test_norm),log_loss(random_cat_predict1,y_test_norm)
# Out:
# (0.7509752103029852, 0.8089285714285714, 6.599483862672392)

# %%
randomizedCat1_new_test = pd.DataFrame()
randomizedCat1_new_test["Aopplicant_ID"]= TEST["Applicant_ID"]
randomizedCat1_new_test["default_status"] =randomized_cat1.predict_proba(new_test)[:,1]

randomizedCat1_new_test
# Out:
#        Aopplicant_ID  default_status
# 0      Apcnt_1000032        0.398917
# 1      Apcnt_1000048        0.438655
# 2      Apcnt_1000052        0.299460
# 3      Apcnt_1000076        0.738836
# 4      Apcnt_1000080        0.161049
# ...              ...             ...
# 23995   Apcnt_999940        0.725013
# 23996   Apcnt_999956        0.105235
# 23997   Apcnt_999976        0.368910
# 23998   Apcnt_999984        0.613118
# 23999   Apcnt_999992        0.153936
#
# [24000 rows x 2 columns]

# %%
randomizedCat1_new_test.to_csv("Randomized_cat1.csv", index= False)
